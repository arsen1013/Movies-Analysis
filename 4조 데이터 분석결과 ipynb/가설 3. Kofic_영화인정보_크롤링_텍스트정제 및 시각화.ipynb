# %%
# 명량 크롤링 코드

import requests
from bs4 import BeautifulSoup
from pandas import read_excel, DataFrame, merge
import pandas as pd
import json

url1 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=1&itemPerPage=100'
rq1 = requests.get(url1)
html1 = rq1.text
d1 = json.loads(html1)
people_list1 = []

for b1 in d1['peopleListResult']['peopleList']:
    people_list1.append([b1['peopleNm'],b1['peopleNmEn'],b1['peopleNmEn'],b1['repRoleNm'],b1['filmoNames']])

url2 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=2&itemPerPage=100'
rq2 = requests.get(url2)
html2 = rq2.text
d2 = json.loads(html2)
people_list2 = []

for b2 in d2['peopleListResult']['peopleList']:
    people_list2.append([b2['peopleNm'],b2['peopleNmEn'],b2['peopleNmEn'],b2['repRoleNm'],b2['filmoNames']])

url3 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=3&itemPerPage=100'
rq3 =requests.get(url3)
html3 = rq3.text
d3 = json.loads(html3)
people_list3 = []

for b3 in d3['peopleListResult']['peopleList']:
    people_list3.append([b3['peopleNm'],b3['peopleNmEn'],b3['peopleNmEn'],b3['repRoleNm'],b3['filmoNames']])

url4 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=4&itemPerPage=100'
rq4 =requests.get(url4)
html4 = rq4.text
d4 = json.loads(html4)
people_list4 = []

for b4 in d4['peopleListResult']['peopleList']:
    people_list4.append([b4['peopleNm'],b4['peopleNmEn'],b4['peopleNmEn'],b4['repRoleNm'],b4['filmoNames']])
    
url5 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=5&itemPerPage=100'
rq5 =requests.get(url5)
html5 = rq5.text
d5 = json.loads(html5)
people_list5 = []

for b5 in d5['peopleListResult']['peopleList']:
    people_list5.append([b5['peopleNm'],b5['peopleNmEn'],b5['peopleNmEn'],b5['repRoleNm'],b5['filmoNames']])
    
url6 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=6&itemPerPage=100'
rq6 =requests.get(url6)
html6 = rq6.text
d6 = json.loads(html6)
people_list6 = []

for b6 in d6['peopleListResult']['peopleList']:
    people_list6.append([b6['peopleNm'],b6['peopleNmEn'],b6['peopleNmEn'],b6['repRoleNm'],b6['filmoNames']])
    
url7 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=명량&curPage=7&itemPerPage=100'
rq7 =requests.get(url7)
html7 = rq7.text
d7 = json.loads(html7)
people_list7 = []

for b7 in d7['peopleListResult']['peopleList']:
    people_list7.append([b7['peopleNm'],b7['peopleNmEn'],b7['peopleNmEn'],b7['repRoleNm'],b7['filmoNames']])

df_1 = pd.DataFrame(people_list1)
df_2 = pd.DataFrame(people_list2)
df_3 = pd.DataFrame(people_list3)
df_4 = pd.DataFrame(people_list4)
df_5 = pd.DataFrame(people_list5)
df_6 = pd.DataFrame(people_list6)
df_7 = pd.DataFrame(people_list7)
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7], ignore_index=True)
df.to_csv("movie1_people_list.csv", mode='w', encoding='utf-8', index=False)

# %%
data1 = pd.read_csv('movie1_people_list.csv')

# %%
data1
# Out:
#            0                 1                 2          3  \
# 0        정덕문    Jeong Deok mun    Jeong Deok mun   VFX 아티스트
# 1        최인선      CHOI In-seon      CHOI In-seon        DI팀
# 2        조수정               NaN               NaN     온라인마케팅
# 3        윤도영               NaN               NaN        의상팀
# 4        김수완               NaN               NaN  홍보/마케팅 진행
# ..       ...               ...               ...        ...
# 655      박영찬               NaN               NaN       케이블맨
# 656      강수진               NaN               NaN        조명팀
# 657      강성민               NaN               NaN     온라인마케팅
# 658      강병욱  Kang Byoung-wook  Kang Byoung-wook        소품팀
# 659  오타니 료헤이      OTANI Ryohei      OTANI Ryohei         배우
#
#                                                      4
# 0    고질라 VS. 콩|잭 스나이더의 저스티스 리그|힘을 내요, 미스터 리|나랏말싸미|손...
# 1    최선의 삶|애비규환|국도극장: 감독판|국도극장|집 이야기|윤희에게|버티고|타짜: 원...
# 2    노회찬6411|내겐 너무 소중한 너|빛나는 순간|소리도 없이|호텔 레이크|자산어보|...
# ...

# %%
actor1 = data1[data1['3'] == '배우']

# %%
actor1.drop(columns=["3"],inplace=True)
# Out:
# C:\Users\master\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
actor1.to_csv("movie1_actor1_list.csv", mode='w', encoding='utf-8', index=False)

# %%
actor = pd.read_csv('movie1_actor1_list.csv')

# %%
actor.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 4    object
# dtype: object

# %%
category = pd.DataFrame(actor['4'].str.count('\|'))
category.columns = ['filmocounts']
category
# Out:
#     filmocounts
# 0            32
# 1            50
# 2            31
# 3             6
# 4            42
# 5            30
# 6            26
# 7             3
# 8             7
# 9            21
# 10           10
# 11           31
# 12            8
# 13           49
# 14           20
# 15           16
# 16           18
# 17           28
# 18           24
# 19           35
# 20           29
# 21           18
# 22           12
# 23           16
# 24           24
# 25           40
# 26            2
# 27            3
# 28           35
# 29            7
# 30            2
# 31           16
# 32            1
# 33            3
# 34            1
# 35            1
# 36            0
# 37            0
# 38            0
# 39            0
# 40            0
# 41            0
# 42            0
# 43            1
# 44            0
# 45            5

# %%
actor_data = pd.concat([actor, category], axis=1)
actor_data
# Out:
#           0                1                2  \
# 0       김태훈      KIM Tae-hun      KIM Tae-hun
# 1       조진웅    CHO Jin-woong    CHO Jin-woong
# 2       주석태      JOO Suk-tae      JOO Suk-tae
# 3       강태영    KANG Taeyoung    KANG Taeyoung
# 4       한이진      HAN Iee-jin      HAN Iee-jin
# 5       김강일      KIM Kang-il      KIM Kang-il
# 6       장준녕  JANG Jun-nyeong  JANG Jun-nyeong
# 7       박선용              NaN              NaN
# 8       박보검      PARK Bo-gum      PARK Bo-gum
# 9        진구          JIN Goo          JIN Goo
# 10      박노식     PARK Nou-sik     PARK Nou-sik
# 11      최민식    CHOI Min-shik    CHOI Min-shik
# 12      김길동     KIM Gil-dong     KIM Gil-dong
# 13      신유람     SHIN Yoo-ram     SHIN Yoo-ram
# 14      김인우       KIM In-woo       KIM In-woo
# 15       권율         KWON Yul         KWON Yul
# 16      조복래       JO Bok-rae       JO Bok-rae
# 17      김원해      KIM Won-hae      KIM Won-hae
# 18      이해영    LEE Hae-young    LEE Hae-young
# ...

# %%
#출연 배우 중 작품 활동이 제일 왕성한 순서대로 정렬
actor1_data = actor_data.sort_values(by=["filmocounts"], ascending=[False])
actor1_data
# Out:
#           0                1                2  \
# 1       조진웅    CHO Jin-woong    CHO Jin-woong
# 13      신유람     SHIN Yoo-ram     SHIN Yoo-ram
# 4       한이진      HAN Iee-jin      HAN Iee-jin
# 25      최덕문     CHOI Duk-mun     CHOI Duk-mun
# 19      이주실       LEE Ju-sil       LEE Ju-sil
# 28      류승룡  RYU Seung-ryong  RYU Seung-ryong
# 0       김태훈      KIM Tae-hun      KIM Tae-hun
# 11      최민식    CHOI Min-shik    CHOI Min-shik
# 2       주석태      JOO Suk-tae      JOO Suk-tae
# 5       김강일      KIM Kang-il      KIM Kang-il
# 20      김명곤    KIM Myung-kon    KIM Myung-kon
# 17      김원해      KIM Won-hae      KIM Won-hae
# 6       장준녕  JANG Jun-nyeong  JANG Jun-nyeong
# 18      이해영    LEE Hae-young    LEE Hae-young
# 24      이승준    LEE Seung-jun    LEE Seung-jun
# 9        진구          JIN Goo          JIN Goo
# 14      김인우       KIM In-woo       KIM In-woo
# 21      문영동   MUN Yeong-dong   MUN Yeong-dong
# 16      조복래       JO Bok-rae       JO Bok-rae
# ...

# %%
# 작품 활동 왕성한 상위 5 출연 배우 바차트 시각화

actor1_filmotop = actor1_data.head(5)
filmotop1 = actor1_filmotop[['0','filmocounts']]
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
sns.set(style='darkgrid')
ax = plt.xticks(rotation = 0,font = 'Malgun Gothic')
ax = sns.barplot(x="0", y="filmocounts", data=filmotop1, palette = 'bone')
ax.set_title("명량 출연 배우 상위 개별 필모그래피 수", alpha = 0.7, font = 'Malgun Gothic', fontsize = 15);

# %%
# 출연 배우 필모그래피 수 히스토그램 시각화

import seaborn as sns
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)
sns.set(style='white')

filmocounts1 = sns.distplot(actor1_data['filmocounts'],bins=10,
             color = 'cadetblue',
             hist = True, kde = False, rug = False)
filmocounts1.set_title("명량 출연 배우들 필모그래피 분포", font='Malgun Gothic',alpha = 0.8, fontsize = 15);
# Out:
# C:\Users\master\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 극한직업 크롤링 코드

import requests
from bs4 import BeautifulSoup
from pandas import read_excel, DataFrame, merge
import pandas as pd
import json

url1 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=1&itemPerPage=100'
rq1 = requests.get(url1)
html1 = rq1.text
d1 = json.loads(html1)
people_list1 = []

for b1 in d1['peopleListResult']['peopleList']:
    people_list1.append([b1['peopleNm'],b1['peopleNmEn'],b1['peopleNmEn'],b1['repRoleNm'],b1['filmoNames']])

url2 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=2&itemPerPage=100'
rq2 = requests.get(url2)
html2 = rq2.text
d2 = json.loads(html2)
people_list2 = []

for b2 in d2['peopleListResult']['peopleList']:
    people_list2.append([b2['peopleNm'],b2['peopleNmEn'],b2['peopleNmEn'],b2['repRoleNm'],b2['filmoNames']])

url3 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=3&itemPerPage=100'
rq3 =requests.get(url3)
html3 = rq3.text
d3 = json.loads(html3)
people_list3 = []

for b3 in d3['peopleListResult']['peopleList']:
    people_list3.append([b3['peopleNm'],b3['peopleNmEn'],b3['peopleNmEn'],b3['repRoleNm'],b3['filmoNames']])

url4 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=4&itemPerPage=100'
rq4 =requests.get(url4)
html4 = rq4.text
d4 = json.loads(html4)
people_list4 = []

for b4 in d4['peopleListResult']['peopleList']:
    people_list4.append([b4['peopleNm'],b4['peopleNmEn'],b4['peopleNmEn'],b4['repRoleNm'],b4['filmoNames']])
    
url5 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=5&itemPerPage=100'
rq5 =requests.get(url5)
html5 = rq5.text
d5 = json.loads(html5)
people_list5 = []

for b5 in d5['peopleListResult']['peopleList']:
    people_list5.append([b5['peopleNm'],b5['peopleNmEn'],b5['peopleNmEn'],b5['repRoleNm'],b5['filmoNames']])
    
url6 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=극한직업&curPage=6&itemPerPage=100'
rq6 =requests.get(url6)
html6 = rq6.text
d6 = json.loads(html6)
people_list6 = []

for b6 in d6['peopleListResult']['peopleList']:
    people_list6.append([b6['peopleNm'],b6['peopleNmEn'],b6['peopleNmEn'],b6['repRoleNm'],b6['filmoNames']])


df_1 = pd.DataFrame(people_list1)
df_2 = pd.DataFrame(people_list2)
df_3 = pd.DataFrame(people_list3)
df_4 = pd.DataFrame(people_list4)
df_5 = pd.DataFrame(people_list5)
df_6 = pd.DataFrame(people_list6)
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6], ignore_index=True)
df.to_csv("movie2_people_list.csv", mode='w', encoding='utf-8', index=False)

# %%
data2 = pd.read_csv('movie2_people_list.csv')

# %%
data2
# Out:
#        0                 1                 2         3  \
# 0    신승민               NaN               NaN       촬영팀
# 1    정윤상               NaN               NaN       제작팀
# 2    강경근  KANG Kyoung-geun  KANG Kyoung-geun        조명
# 3    김성종    KIM Seong-jong    KIM Seong-jong   액션/스턴트팀
# 4    박영무            YINGWU            YINGWU      특수분장
# ..   ...               ...               ...       ...
# 574  이병헌   LEE Byoung-heon   LEE Byoung-heon        감독
# 575  이덕렬               NaN               NaN       촬영팀
# 576  김미혜        KIM Mi-hye        KIM Mi-hye      프로듀서
# 577  류승룡   RYU Seung-ryong   RYU Seung-ryong        배우
# 578  문충일               NaN               NaN  시나리오(각본)
#
#                                                      4
# 0       보이스|스웨그|앙상블|젊은이의 양지|욕창|야구소녀|저 산 너머|성혜의 나라|극한직업
# 1    싱크홀|시동|극한직업|침묵|청년경찰|최종병기 활|돌아오는 길|폭풍전야|보트|세븐 데...
# 2    쇼미더고스트|내일의 기억|소리도 없이|런 보이 런|프랑스여자|저 산 너머|남산의 부...
# 3    방법: 재차의|반도|피원에이치 : 새로운 세계의 시작 |오케이 마담|강철비2: 정상...
# ...

# %%
actor2 = data2[data2['3'] == '배우']
actor2
# Out:
#        0                1                2   3  \
# 19   송영규   SONG Yeong-gyu   SONG Yeong-gyu  배우
# 22   류제윤      Ryoo Jeyoon      Ryoo Jeyoon  배우
# 36   김남우              NaN              NaN  배우
# 91   이중옥     LEE Joong-ok     LEE Joong-ok  배우
# 92   이동용              NaN              NaN  배우
# ..   ...              ...              ...  ..
# 568  장진희     JANG Jin-hee     JANG Jin-hee  배우
# 571  김명준    KIM Myung-jun    KIM Myung-jun  배우
# 572  한준우     HAN Joon-woo     HAN Joon-woo  배우
# 573  양현민    YANG Hyun-min    YANG Hyun-min  배우
# 577  류승룡  RYU Seung-ryong  RYU Seung-ryong  배우
#
#                                                      4
# 19   강릉|수색자|킬링톡|창애 (짐승잡는 덫)|균|야구소녀|프랑스여자|극한직업|하프|굿모...
# 22                           공포체험단 곤지암편|극한직업|히치하이크|곤지암
# 36                                      최면|소리도 없이|극한직업
# 91   방법: 재차의|히트맨|천문: 하늘에 묻는다|스텔라|돌멩이|극한직업|버닝|마약왕|탯줄...
# 92   깨복쟁이|기적|이웃사촌|천문: 하늘에 묻는다|양자물리학|봉오동 전투|기생충|자전차왕...
# ..                                                 ...
# ...

# %%
actor2.to_csv("movie2_actor_list.csv", mode='w', encoding='utf-8', index=False)
actor = pd.read_csv('movie2_actor_list.csv')

# %%
category = pd.DataFrame(actor['4'].str.count('\|'))
category.columns = ['filmocounts']
actor_data = pd.concat([actor, category], axis=1)
actor_data
# Out:
#       0                1                2   3  \
# 0   송영규   SONG Yeong-gyu   SONG Yeong-gyu  배우
# 1   류제윤      Ryoo Jeyoon      Ryoo Jeyoon  배우
# 2   김남우              NaN              NaN  배우
# 3   이중옥     LEE Joong-ok     LEE Joong-ok  배우
# 4   이동용              NaN              NaN  배우
# ..  ...              ...              ...  ..
# 72  장진희     JANG Jin-hee     JANG Jin-hee  배우
# 73  김명준    KIM Myung-jun    KIM Myung-jun  배우
# 74  한준우     HAN Joon-woo     HAN Joon-woo  배우
# 75  양현민    YANG Hyun-min    YANG Hyun-min  배우
# 76  류승룡  RYU Seung-ryong  RYU Seung-ryong  배우
#
#                                                     4  filmocounts
# 0   강릉|수색자|킬링톡|창애 (짐승잡는 덫)|균|야구소녀|프랑스여자|극한직업|하프|굿모...            9
# 1                           공포체험단 곤지암편|극한직업|히치하이크|곤지암            3
# 2                                      최면|소리도 없이|극한직업            2
# 3   방법: 재차의|히트맨|천문: 하늘에 묻는다|스텔라|돌멩이|극한직업|버닝|마약왕|탯줄...           14
# 4   깨복쟁이|기적|이웃사촌|천문: 하늘에 묻는다|양자물리학|봉오동 전투|기생충|자전차왕...            9
# ...

# %%
#출연 배우 중 작품 활동이 제일 왕성한 순서대로 정렬
actor2_data = actor_data.sort_values(by=["filmocounts"], ascending=[False])
actor2_data
# Out:
#       0                1                2   3  \
# 26  오정세       OH Jung-se       OH Jung-se  배우
# 59  이광기              NaN              NaN  배우
# 63  김의성     KIM Eui-sung     KIM Eui-sung  배우
# 23  김종수     KIM Jong-soo     KIM Jong-soo  배우
# 76  류승룡  RYU Seung-ryong  RYU Seung-ryong  배우
# ..  ...              ...              ...  ..
# 47   윤설              NaN              NaN  배우
# 61  고경진              NaN              NaN  배우
# 60  고관형              NaN              NaN  배우
# 58  구성환              NaN              NaN  배우
# 51   김천              NaN              NaN  배우
#
#                                                     4  filmocounts
# 26  장르만 로맨스|크리스마스 선물(가제)|나는 나를 해고하지 않는다|콜|여름방학|극한직...           72
# 59  광대들: 풍문조작단|봉오동 전투|엑시트|롱 리브 더 킹: 목포 영웅|걸캅스|극한직업...           60
# 63  외계+인|세자매|특송|자산어보|나의 촛불|돌멩이|어쩌다, 결혼|극한직업|창궐|도청(...           48
# 23  킹메이커|헌트|삼진그룹 영어토익반|드림(가제)|오케이 마담|야구소녀|시동|나를 찾아...           44
# 76  장르만 로맨스|비광|정가네 목장(가제)|인생은 아름다워|자산어보|극한직업|7년의 밤...           35
# ...

# %%
# 작품 활동 왕성한 상위 5 출연 배우 바차트 시각화

actor2_filmotop = actor2_data.head(5)
filmotop2 = actor2_filmotop[['0','filmocounts']]

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
sns.set(style='whitegrid')
ax = plt.xticks(rotation = 0,font = 'Malgun Gothic')
ax = sns.barplot(x="0", y="filmocounts", data=filmotop2, palette = 'YlOrBr')
ax.set_title("극한직업 출연 배우 상위 개별 필모그래피 수", font = 'Malgun Gothic',alpha = 0.7, fontsize = 15);

# %%
# 출연 배우 필모그래피 수 히스토그램 시각화

import seaborn as sns
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
sns.set(style='white')
matplotlib.rc('axes',unicode_minus = False)
filmocounts2 = sns.distplot(actor2_data['filmocounts'],bins=10,
             color = 'gold',
             hist = True, kde = False, rug = False);
filmocounts2.set_title("극한직업 출연 배우들 필모그래피 분포", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);
# Out:
# C:\Users\master\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 신과함께 - 죄와 벌 크롤링 코드

import requests
from bs4 import BeautifulSoup
from pandas import read_excel, DataFrame, merge
import pandas as pd
import json

url1 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=1&itemPerPage=100'
rq1 = requests.get(url1)
html1 = rq1.text
d1 = json.loads(html1)
people_list1 = []

for b1 in d1['peopleListResult']['peopleList']:
    people_list1.append([b1['peopleNm'],b1['peopleNmEn'],b1['peopleNmEn'],b1['repRoleNm'],b1['filmoNames']])

url2 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=2&itemPerPage=100'
rq2 = requests.get(url2)
html2 = rq2.text
d2 = json.loads(html2)
people_list2 = []

for b2 in d2['peopleListResult']['peopleList']:
    people_list2.append([b2['peopleNm'],b2['peopleNmEn'],b2['peopleNmEn'],b2['repRoleNm'],b2['filmoNames']])

url3 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=3&itemPerPage=100'
rq3 =requests.get(url3)
html3 = rq3.text
d3 = json.loads(html3)
people_list3 = []

for b3 in d3['peopleListResult']['peopleList']:
    people_list3.append([b3['peopleNm'],b3['peopleNmEn'],b3['peopleNmEn'],b3['repRoleNm'],b3['filmoNames']])

url4 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=4&itemPerPage=100'
rq4 =requests.get(url4)
html4 = rq4.text
d4 = json.loads(html4)
people_list4 = []

for b4 in d4['peopleListResult']['peopleList']:
    people_list4.append([b4['peopleNm'],b4['peopleNmEn'],b4['peopleNmEn'],b4['repRoleNm'],b4['filmoNames']])
    
url5 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=5&itemPerPage=100'
rq5 =requests.get(url5)
html5 = rq5.text
d5 = json.loads(html5)
people_list5 = []

for b5 in d5['peopleListResult']['peopleList']:
    people_list5.append([b5['peopleNm'],b5['peopleNmEn'],b5['peopleNmEn'],b5['repRoleNm'],b5['filmoNames']])
    
url6 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=6&itemPerPage=100'
rq6 =requests.get(url6)
html6 = rq6.text
d6 = json.loads(html6)
people_list6 = []

for b6 in d6['peopleListResult']['peopleList']:
    people_list6.append([b6['peopleNm'],b6['peopleNmEn'],b6['peopleNmEn'],b6['repRoleNm'],b6['filmoNames']])
    
url7 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=7&itemPerPage=100'
rq7 =requests.get(url7)
html7 = rq7.text
d7 = json.loads(html7)
people_list7 = []

for b7 in d7['peopleListResult']['peopleList']:
    people_list7.append([b7['peopleNm'],b7['peopleNmEn'],b7['peopleNmEn'],b7['repRoleNm'],b7['filmoNames']])
        
url8 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=8&itemPerPage=100'
rq8 =requests.get(url8)
html8 = rq8.text
d8 = json.loads(html8)
people_list8 = []

for b8 in d8['peopleListResult']['peopleList']:
    people_list8.append([b8['peopleNm'],b8['peopleNmEn'],b8['peopleNmEn'],b8['repRoleNm'],b8['filmoNames']])
    
url9 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=신과함께 - 죄와 벌&curPage=9&itemPerPage=100'
rq9 =requests.get(url9)
html9 = rq9.text
d9 = json.loads(html9)
people_list9 = []

for b9 in d9['peopleListResult']['peopleList']:
    people_list9.append([b9['peopleNm'],b9['peopleNmEn'],b9['peopleNmEn'],b9['repRoleNm'],b9['filmoNames']])


df_1 = pd.DataFrame(people_list1)
df_2 = pd.DataFrame(people_list2)
df_3 = pd.DataFrame(people_list3)
df_4 = pd.DataFrame(people_list4)
df_5 = pd.DataFrame(people_list5)
df_6 = pd.DataFrame(people_list6)
df_7 = pd.DataFrame(people_list7)
df_8 = pd.DataFrame(people_list8)
df_9 = pd.DataFrame(people_list9)
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9], ignore_index=True)
df.to_csv("movie3_people_list.csv", mode='w', encoding='utf-8', index=False)

# %%
data3 = pd.read_csv('movie3_people_list.csv')

# %%
data3
# Out:
#        0                 1                 2          3  \
# 0     마현               NaN               NaN        연출팀
# 1    정경재  Chung Kyoung Jae  Chung Kyoung Jae         투자
# 2    이경진               NaN               NaN  VFX 매니지먼트
# 3    김유나               NaN               NaN   VFX 아티스트
# 4    박영무            YINGWU            YINGWU       특수분장
# ..   ...               ...               ...        ...
# 795  최용훈               NaN               NaN         배우
# 796  오달수         OH Dal-su         OH Dal-su         배우
# 797  김하늘       KIM Ha-neul       KIM Ha-neul         배우
# 798  차태현      CHA Tae-hyun      CHA Tae-hyun         배우
# 799  김해숙      KIM Hae-sook      KIM Hae-sook         배우
#
#                                                      4
# 0    국제수사|히트맨|천문: 하늘에 묻는다|안시성|마녀|신과함께-인과 연|챔피언|살인소설...
# 1    모가디슈|아이|기적|삼진그룹 영어토익반|피원에이치 : 새로운 세계의 시작 |강철비2...
# 2    보이스|새해전야|기생충|신과함께-인과 연|신과함께-죄와 벌|대장 김창수|판도라|대호...
# 3    보이스|모가디슈|반도|소리꾼|천문: 하늘에 묻는다|신비아파트 극장판 하늘도깨비 대 ...
# ...

# %%
actor3 = data3[data3['3'] == '배우']
actor3
# Out:
#        0                 1                 2   3  \
# 35    장광        JANG Kwang        JANG Kwang  배우
# 47   김기태        KIM Ki-tae        KIM Ki-tae  배우
# 53   강길우      KANG Gil-woo      KANG Gil-woo  배우
# 54   예수정       YE Soo-jung       YE Soo-jung  배우
# 118  오희준        OH Hee-jun        OH Hee-jun  배우
# 130  임원희       LIM Won-hee       LIM Won-hee  배우
# 182  박윤호      PARK Yoon-ho      PARK Yoon-ho  배우
# 195  강소백               NaN               NaN  배우
# 259  김지나         KIM Ji-na         KIM Ji-na  배우
# 262  임철수      LIM Chul-soo      LIM Chul-soo  배우
# 286  김태준      KIM Tae-joon      KIM Tae-joon  배우
# 291  하정우       HA Jung-woo       HA Jung-woo  배우
# 295  이승준               NaN               NaN  배우
# 303  이준혁      LEE Jun-hyuk      LEE Jun-hyuk  배우
# 311  도경수     DOH Kyung-soo     DOH Kyung-soo  배우
# 314  이정재      LEE Jung-jae      LEE Jung-jae  배우
# 322  양지수        YANG Ji-su        YANG Ji-su  배우
# 328  김그림       KIM Geu-rim       KIM Geu-rim  배우
# ...

# %%
actor3.drop(columns=["3"],inplace=True)
actor3.to_csv("movie3_actor_list.csv", mode='w', encoding='utf-8', index=False)
actor = pd.read_csv('movie3_actor_list.csv')
# Out:
# C:\Users\master\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
category = pd.DataFrame(actor['4'].str.count('\|'))
category.columns = ['filmocounts']
category
# Out:
#     filmocounts
# 0            55
# 1            11
# 2            20
# 3            39
# 4            54
# 5            27
# 6            29
# 7             4
# 8             4
# 9             7
# 10           32
# 11           43
# 12           17
# 13            6
# 14            8
# 15           35
# 16            9
# 17           15
# 18            6
# 19            3
# 20           18
# 21           24
# 22           83
# 23           13
# 24           14
# 25            9
# 26           24
# 27           45
# 28           10
# 29           29
# 30            3
# 31           18
# 32           10
# 33           14
# 34            2
# 35           59
# 36           16
# 37           17
# 38           47

# %%
actor_data = pd.concat([actor, category], axis=1)
actor_data
# Out:
#       0                 1                 2  \
# 0    장광        JANG Kwang        JANG Kwang
# 1   김기태        KIM Ki-tae        KIM Ki-tae
# 2   강길우      KANG Gil-woo      KANG Gil-woo
# 3   예수정       YE Soo-jung       YE Soo-jung
# 4   오희준        OH Hee-jun        OH Hee-jun
# 5   임원희       LIM Won-hee       LIM Won-hee
# 6   박윤호      PARK Yoon-ho      PARK Yoon-ho
# 7   강소백               NaN               NaN
# 8   김지나         KIM Ji-na         KIM Ji-na
# 9   임철수      LIM Chul-soo      LIM Chul-soo
# 10  김태준      KIM Tae-joon      KIM Tae-joon
# 11  하정우       HA Jung-woo       HA Jung-woo
# 12  이승준               NaN               NaN
# 13  이준혁      LEE Jun-hyuk      LEE Jun-hyuk
# 14  도경수     DOH Kyung-soo     DOH Kyung-soo
# 15  이정재      LEE Jung-jae      LEE Jung-jae
# 16  양지수        YANG Ji-su        YANG Ji-su
# 17  김그림       KIM Geu-rim       KIM Geu-rim
# 18  정순원    JEONG Soon-won    JEONG Soon-won
# 19  이지향               NaN               NaN
# ...

# %%
#출연 배우 중 작품 활동이 제일 왕성한 순서대로 정렬
actor3_data = actor_data.sort_values(by=["filmocounts"], ascending=[False])
actor3_data
# Out:
#       0                 1                 2  \
# 22  이경영  LEE Gyoung-young  LEE Gyoung-young
# 35  오달수         OH Dal-su         OH Dal-su
# 0    장광        JANG Kwang        JANG Kwang
# 4   오희준        OH Hee-jun        OH Hee-jun
# 38  김해숙      KIM Hae-sook      KIM Hae-sook
# 27  마동석           Don LEE           Don LEE
# 11  하정우       HA Jung-woo       HA Jung-woo
# 3   예수정       YE Soo-jung       YE Soo-jung
# 15  이정재      LEE Jung-jae      LEE Jung-jae
# 10  김태준      KIM Tae-joon      KIM Tae-joon
# 29  김수안         KIM Su-an         KIM Su-an
# 6   박윤호      PARK Yoon-ho      PARK Yoon-ho
# 5   임원희       LIM Won-hee       LIM Won-hee
# 26  성유빈       SUNG Yu-bin       SUNG Yu-bin
# 21  김민종      KIM Min-jong      KIM Min-jong
# 2   강길우      KANG Gil-woo      KANG Gil-woo
# 20  김향기      KIM Hyang-gi      KIM Hyang-gi
# 31  김동욱     KIM Dong-wook     KIM Dong-wook
# 37  차태현      CHA Tae-hyun      CHA Tae-hyun
# 12  이승준               NaN               NaN
# ...

# %%
# 작품 활동 왕성한 상위 5 출연 배우 바차트 시각화

actor3_filmotop = actor3_data.head(5)
filmotop3 = actor3_filmotop[['0','filmocounts']]

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'NanumBarunGothic') 
sns.set(style='darkgrid')
ax = plt.xticks(rotation = 0,font = 'Malgun Gothic')
ax = sns.barplot(x="0", y="filmocounts", data=filmotop3, palette = 'PuBuGn')
ax.set_title("신과함께-죄와 벌 출연 배우 상위 개별 필모그래피 수", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);

# %%
# 출연 배우 필모그래피 수 히스토그램 시각화

import seaborn as sns
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
sns.set(style='dark')
matplotlib.rc('axes',unicode_minus = False)
filmocounts3 = sns.distplot(actor3_data['filmocounts'],bins=10,
             color = 'midnightblue',
             hist = True, kde = False, rug = False);
filmocounts3.set_title("신과함께-죄와 벌 출연 배우들 필모그래피 분포", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);
# Out:
# C:\Users\master\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 극한직업 크롤링 코드

import requests
from bs4 import BeautifulSoup
from pandas import read_excel, DataFrame, merge
import pandas as pd
import json

url1 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=1&itemPerPage=100'
rq1 = requests.get(url1)
html1 = rq1.text
d1 = json.loads(html1)
people_list1 = []

for b1 in d1['peopleListResult']['peopleList']:
    people_list1.append([b1['peopleNm'],b1['peopleNmEn'],b1['peopleNmEn'],b1['repRoleNm'],b1['filmoNames']])

url2 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=2&itemPerPage=100'
rq2 = requests.get(url2)
html2 = rq2.text
d2 = json.loads(html2)
people_list2 = []

for b2 in d2['peopleListResult']['peopleList']:
    people_list2.append([b2['peopleNm'],b2['peopleNmEn'],b2['peopleNmEn'],b2['repRoleNm'],b2['filmoNames']])

url3 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=3&itemPerPage=100'
rq3 =requests.get(url3)
html3 = rq3.text
d3 = json.loads(html3)
people_list3 = []

for b3 in d3['peopleListResult']['peopleList']:
    people_list3.append([b3['peopleNm'],b3['peopleNmEn'],b3['peopleNmEn'],b3['repRoleNm'],b3['filmoNames']])

url4 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=4&itemPerPage=100'
rq4 =requests.get(url4)
html4 = rq4.text
d4 = json.loads(html4)
people_list4 = []

for b4 in d4['peopleListResult']['peopleList']:
    people_list4.append([b4['peopleNm'],b4['peopleNmEn'],b4['peopleNmEn'],b4['repRoleNm'],b4['filmoNames']])
    
url5 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=5&itemPerPage=100'
rq5 =requests.get(url5)
html5 = rq5.text
d5 = json.loads(html5)
people_list5 = []

for b5 in d5['peopleListResult']['peopleList']:
    people_list5.append([b5['peopleNm'],b5['peopleNmEn'],b5['peopleNmEn'],b5['repRoleNm'],b5['filmoNames']])
    
url6 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=국제시장&curPage=6&itemPerPage=100'
rq6 =requests.get(url6)
html6 = rq6.text
d6 = json.loads(html6)
people_list6 = []

for b6 in d6['peopleListResult']['peopleList']:
    people_list6.append([b6['peopleNm'],b6['peopleNmEn'],b6['peopleNmEn'],b6['repRoleNm'],b6['filmoNames']])


df_1 = pd.DataFrame(people_list1)
df_2 = pd.DataFrame(people_list2)
df_3 = pd.DataFrame(people_list3)
df_4 = pd.DataFrame(people_list4)
df_5 = pd.DataFrame(people_list5)
df_6 = pd.DataFrame(people_list6)
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6], ignore_index=True)
df.to_csv("movie4_people_list.csv", mode='w', encoding='utf-8', index=False)

# %%
data4 = pd.read_csv('movie4_people_list.csv')

# %%
data4
# Out:
#         0               1               2          3  \
# 0     김상훈   Kim Sang-hoon   Kim Sang-hoon    액션/스턴트팀
# 1     장영남  JANG Yeong-nam  JANG Yeong-nam         배우
# 2     최인선    CHOI In-seon    CHOI In-seon        DI팀
# 3     최가영    CHOI Ga-yung    CHOI Ga-yung  VFX 매니지먼트
# 4     김형석  KIM Hyung-seok  KIM Hyung-seok         촬영
# ..    ...             ...             ...        ...
# 565   강다원             NaN             NaN        의상팀
# 566   황현진  Hwang Hyun-jin  Hwang Hyun-jin        연출팀
# 567   황태웅             NaN             NaN        제작팀
# 568   황정민             NaN             NaN        미술팀
# 569  황보하림             NaN             NaN        조명팀
#
#                                                      4
# 0    방법: 재차의|샤크 : 더 비기닝|검객|블랙머니|장사리 : 잊혀진 영웅들|양자물리학...
# 1    F20|소방관|서복|변신|증인|협상|미쓰백|나와 봄날의 약속|바람 바람 바람|임금님...
# 2    최선의 삶|애비규환|국도극장: 감독판|국도극장|집 이야기|윤희에게|버티고|타짜: 원...
# 3    인질|싱크홀|아이|#살아있다|히트맨|백두산|시동|가장 보통의 연애|타짜: 원 아이드...
# ...

# %%
actor4 = data4[data4['3'] == '배우']
actor4
# Out:
#        0                1                2   3  \
# 1    장영남   JANG Yeong-nam   JANG Yeong-nam  배우
# 30   김근영   KIM Geun-yeong   KIM Geun-yeong  배우
# 75   현봉식    HYUN Bong-sik    HYUN Bong-sik  배우
# 126  황인준              NaN              NaN  배우
# 136  라미란        RA Mi-ran        RA Mi-ran  배우
# 160  이소영              NaN              NaN  배우
# 161  유정호     YU  Jeong-ho     YU  Jeong-ho  배우
# 171  김선영    KIM Sun-young    KIM Sun-young  배우
# 191  허동원     HEO Dong-won     HEO Dong-won  배우
# 202  정진영   JUNG Jin-young   JUNG Jin-young  배우
# 203  신정섭  SHIN Jeong-seop  SHIN Jeong-seop  배우
# 208  남진복      NAM Jin-bok      NAM Jin-bok  배우
# 214  김하연      KIM Ha-yeon      KIM Ha-yeon  배우
# 228  박혜진     PARK Hye-jin     PARK Hye-jin  배우
# 239  정영기   JEONG Young-ki   JEONG Young-ki  배우
# 312  강신철   GANG Sin-cheol   GANG Sin-cheol  배우
# 314  박길수     PARK Gil-soo     PARK Gil-soo  배우
# 316  손영순   SON Young-soon   SON Young-soon  배우
# 318  김슬기      KIM Seul-ki      KIM Seul-ki  배우
# ...

# %%
actor4.drop(columns=["3"],inplace=True)
# Out:
# C:\Users\master\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
actor4.to_csv("movie4_actor_list.csv", mode='w', encoding='utf-8', index=False)

# %%
actor = pd.read_csv('movie4_actor_list.csv')

# %%
category = pd.DataFrame(actor['4'].str.count('\|'))
category.columns = ['filmocounts']
actor_data = pd.concat([actor, category], axis=1)
actor_data
# Out:
#       0                1                2  \
# 0   장영남   JANG Yeong-nam   JANG Yeong-nam
# 1   김근영   KIM Geun-yeong   KIM Geun-yeong
# 2   현봉식    HYUN Bong-sik    HYUN Bong-sik
# 3   황인준              NaN              NaN
# 4   라미란        RA Mi-ran        RA Mi-ran
# 5   이소영              NaN              NaN
# 6   유정호     YU  Jeong-ho     YU  Jeong-ho
# 7   김선영    KIM Sun-young    KIM Sun-young
# 8   허동원     HEO Dong-won     HEO Dong-won
# 9   정진영   JUNG Jin-young   JUNG Jin-young
# 10  신정섭  SHIN Jeong-seop  SHIN Jeong-seop
# 11  남진복      NAM Jin-bok      NAM Jin-bok
# 12  김하연      KIM Ha-yeon      KIM Ha-yeon
# 13  박혜진     PARK Hye-jin     PARK Hye-jin
# 14  정영기   JEONG Young-ki   JEONG Young-ki
# 15  강신철   GANG Sin-cheol   GANG Sin-cheol
# 16  박길수     PARK Gil-soo     PARK Gil-soo
# 17  손영순   SON Young-soon   SON Young-soon
# 18  김슬기      KIM Seul-ki      KIM Seul-ki
# 19  이진희      LEE Jin-hee      LEE Jin-hee
# 20  김현중              NaN              NaN
# ...

# %%
#출연 배우 중 작품 활동이 제일 왕성한 순서대로 정렬
actor4_data = actor_data.sort_values(by=["filmocounts"], ascending=[False])
actor4_data
# Out:
#       0                1                2  \
# 24  오달수        OH Dal-su        OH Dal-su
# 16  박길수     PARK Gil-soo     PARK Gil-soo
# 4   라미란        RA Mi-ran        RA Mi-ran
# 1   김근영   KIM Geun-yeong   KIM Geun-yeong
# 9   정진영   JUNG Jin-young   JUNG Jin-young
# 23  황정민   HWANG Jung-min   HWANG Jung-min
# 0   장영남   JANG Yeong-nam   JANG Yeong-nam
# 15  강신철   GANG Sin-cheol   GANG Sin-cheol
# 2   현봉식    HYUN Bong-sik    HYUN Bong-sik
# 6   유정호     YU  Jeong-ho     YU  Jeong-ho
# 10  신정섭  SHIN Jeong-seop  SHIN Jeong-seop
# 17  손영순   SON Young-soon   SON Young-soon
# 13  박혜진     PARK Hye-jin     PARK Hye-jin
# 7   김선영    KIM Sun-young    KIM Sun-young
# 14  정영기   JEONG Young-ki   JEONG Young-ki
# 8   허동원     HEO Dong-won     HEO Dong-won
# 25  김윤진      KIM Yun-jin      KIM Yun-jin
# 26  박영수   PARK Yeong-soo   PARK Yeong-soo
# 18  김슬기      KIM Seul-ki      KIM Seul-ki
# 11  남진복      NAM Jin-bok      NAM Jin-bok
# 30  유재상     YOO Jae-sang     YOO Jae-sang
# ...

# %%
# 작품 활동 왕성한 상위 5 출연 배우 바차트 시각화

actor4_filmotop = actor4_data.head(5)
filmotop4 = actor4_filmotop[['0','filmocounts']]

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'NanumBarunGothic') 
sns.set(style='whitegrid')
ax = plt.xticks(rotation = 0,font = 'Malgun Gothic')
ax = sns.barplot(x="0", y="filmocounts", data=filmotop4, palette = 'Dark2')
ax.set_title("국제시장 출연 배우 상위 개별 필모그래피 수", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);

# %%
# 출연 배우 필모그래피 수 히스토그램 시각화

import seaborn as sns
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
sns.set(style='dark')
matplotlib.rc('axes',unicode_minus = False)
filmocounts4 = sns.distplot(actor4_data['filmocounts'],bins=10,
             color = 'seagreen',
             hist = True, kde = False, rug = False);
filmocounts4.set_title("국제시장 출연 배우들 필모그래피 분포", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);

# %%
# Avengers: Endgame 크롤링 코드

import requests
from bs4 import BeautifulSoup
from pandas import read_excel, DataFrame, merge
import pandas as pd
import json

url1 = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json?key=6d19a06bb170dd56e7e22d21042acae2&filmoNames=Avengers: Endgame&curPage=1&itemPerPage=100'
rq1 = requests.get(url1)
html1 = rq1.text
d1 = json.loads(html1)
people_list1 = []

for b1 in d1['peopleListResult']['peopleList']:
    people_list1.append([b1['peopleNm'],b1['peopleNmEn'],b1['peopleNmEn'],b1['repRoleNm'],b1['filmoNames']])

df_1 = pd.DataFrame(people_list1)
df_1.to_csv("movie5_people_list.csv", mode='w', encoding='utf-8', index=False)

# %%
data5 = pd.read_csv('movie5_people_list.csv')

# %%
data5
# Out:
#               0                   1                   2   3  \
# 0         브리 라슨         Brie Larson         Brie Larson  배우
# 1          조 루소           Joe Russo           Joe Russo  감독
# 2        안소니 루소       Anthony Russo       Anthony Russo  감독
# 3        마크 러팔로        Mark Ruffalo        Mark Ruffalo  배우
# 4        조슈 브롤린         Josh Brolin         Josh Brolin  배우
# 5         카렌 길런        Karen Gillan        Karen Gillan  배우
# 6       크리스 에반스         Chris Evans         Chris Evans  배우
# 7       스칼렛 요한슨  Scarlett Johansson  Scarlett Johansson  배우
# 8      크리스 헴스워스     Chris Hemsworth     Chris Hemsworth  배우
# 9       브래들리 쿠퍼      Bradley Cooper      Bradley Cooper  배우
# 10         돈 치들         Don Cheadle         Don Cheadle  배우
# 11         폴 러드           Paul Rudd           Paul Rudd  배우
# 12  로버트 다우니 주니어   Robert Downey Jr.   Robert Downey Jr.  배우
# 13       제레미 레너       Jeremy Renner       Jeremy Renner  배우
#
#                                                     4
# ...

# %%
actor5 = data5[data5['3'] == '배우']
actor5
# Out:
#               0                   1                   2   3  \
# 0         브리 라슨         Brie Larson         Brie Larson  배우
# 3        마크 러팔로        Mark Ruffalo        Mark Ruffalo  배우
# 4        조슈 브롤린         Josh Brolin         Josh Brolin  배우
# 5         카렌 길런        Karen Gillan        Karen Gillan  배우
# 6       크리스 에반스         Chris Evans         Chris Evans  배우
# 7       스칼렛 요한슨  Scarlett Johansson  Scarlett Johansson  배우
# 8      크리스 헴스워스     Chris Hemsworth     Chris Hemsworth  배우
# 9       브래들리 쿠퍼      Bradley Cooper      Bradley Cooper  배우
# 10         돈 치들         Don Cheadle         Don Cheadle  배우
# 11         폴 러드           Paul Rudd           Paul Rudd  배우
# 12  로버트 다우니 주니어   Robert Downey Jr.   Robert Downey Jr.  배우
# 13       제레미 레너       Jeremy Renner       Jeremy Renner  배우
#
#                                                     4
# 0   어벤져스: 엔드게임|캡틴 마블|블루스 인 인디아|콩: 스컬 아일랜드|프리 파이어|룸...
# 3   다크 워터스 |어벤져스: 엔드게임|어벤져스: 인피니티 워|토르: 라그나로크|나우 유...
# ...

# %%
actor5 = data5[data5['3'] == '배우']

# %%
actor5.drop(columns=["3"],inplace=True)
actor5.to_csv("movie5_actor_list.csv", mode='w', encoding='utf-8', index=False)
# Out:
# C:\Users\master\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
actor = pd.read_csv('movie5_actor_list.csv')

# %%
category = pd.DataFrame(actor['4'].str.count('\|'))
category.columns = ['filmocounts']
category
# Out:
#     filmocounts
# 0             9
# 1            30
# 2            23
# 3             8
# 4            20
# 5            37
# 6            17
# 7            23
# 8            19
# 9            25
# 10           38
# 11           17

# %%
actor_data = pd.concat([actor, category], axis=1)
actor_data
# Out:
#               0                   1                   2  \
# 0         브리 라슨         Brie Larson         Brie Larson
# 1        마크 러팔로        Mark Ruffalo        Mark Ruffalo
# 2        조슈 브롤린         Josh Brolin         Josh Brolin
# 3         카렌 길런        Karen Gillan        Karen Gillan
# 4       크리스 에반스         Chris Evans         Chris Evans
# 5       스칼렛 요한슨  Scarlett Johansson  Scarlett Johansson
# 6      크리스 헴스워스     Chris Hemsworth     Chris Hemsworth
# 7       브래들리 쿠퍼      Bradley Cooper      Bradley Cooper
# 8          돈 치들         Don Cheadle         Don Cheadle
# 9          폴 러드           Paul Rudd           Paul Rudd
# 10  로버트 다우니 주니어   Robert Downey Jr.   Robert Downey Jr.
# 11       제레미 레너       Jeremy Renner       Jeremy Renner
#
#                                                     4  filmocounts
# 0   어벤져스: 엔드게임|캡틴 마블|블루스 인 인디아|콩: 스컬 아일랜드|프리 파이어|룸...            9
# 1   다크 워터스 |어벤져스: 엔드게임|어벤져스: 인피니티 워|토르: 라그나로크|나우 유...           30
# ...

# %%
#출연 배우 중 작품 활동이 제일 왕성한 순서대로 정렬
actor5_data = actor_data.sort_values(by=["filmocounts"], ascending=[False])
actor5_data
# Out:
#               0                   1                   2  \
# 10  로버트 다우니 주니어   Robert Downey Jr.   Robert Downey Jr.
# 5       스칼렛 요한슨  Scarlett Johansson  Scarlett Johansson
# 1        마크 러팔로        Mark Ruffalo        Mark Ruffalo
# 9          폴 러드           Paul Rudd           Paul Rudd
# 2        조슈 브롤린         Josh Brolin         Josh Brolin
# 7       브래들리 쿠퍼      Bradley Cooper      Bradley Cooper
# 4       크리스 에반스         Chris Evans         Chris Evans
# 8          돈 치들         Don Cheadle         Don Cheadle
# 6      크리스 헴스워스     Chris Hemsworth     Chris Hemsworth
# 11       제레미 레너       Jeremy Renner       Jeremy Renner
# 0         브리 라슨         Brie Larson         Brie Larson
# 3         카렌 길런        Karen Gillan        Karen Gillan
#
#                                                     4  filmocounts
# 10  닥터 두리틀|어벤져스: 엔드게임|어벤져스: 인피니티 워|스파이더맨: 홈 커밍|캡틴 ...           38
# 5   블랙 위도우|씽2게더|조조 래빗|결혼 이야기|어벤져스: 엔드게임|개들의 섬|어벤져스...           37
# ...

# %%
# 작품 활동 왕성한 상위 5 출연 배우 바차트 시각화

actor5_filmotop = actor5_data.head(5)
filmotop5 = actor5_filmotop[['0','filmocounts']]

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'NanumBarunGothic') 
sns.set(style='darkgrid')
ax = plt.xticks(rotation = 20,font = 'Malgun Gothic')
ax = sns.barplot(x="0", y="filmocounts", data=filmotop5, palette = 'seismic',alpha = 0.7)
ax.set_title("Avengers: Endgame 출연 배우 상위 개별 필모그래피 수", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);

# %%
# 출연 배우 필모그래피 수 히스토그램 시각화

import seaborn as sns
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
sns.set(style='dark')
matplotlib.rc('axes',unicode_minus = False)
filmocounts5 = sns.distplot(actor5_data['filmocounts'],bins=10,
             color = 'maroon',
             hist = True, kde = False, rug = False);
filmocounts5.set_title("Avengers: Endgame 배우들 필모그래피 분포", font = 'Malgun Gothic', alpha = 0.7, fontsize = 15);
